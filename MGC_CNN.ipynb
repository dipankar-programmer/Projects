# %% [markdown]
# # PIPELINE OF THE MODEL
# ![image.png](attachment:image.png)
# WE USE THE JSON WE CREATED IN THE PREPROCESSING FILE AND THEN USE CNN TO PREDICT THE GENRE

# %% [markdown]
# ### IMPORTING THE LIBRARIES

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "C:/Users/KIIT/data/genres_original/data_10.json"

# %% [markdown]
# ### UPLOADING THE JSON FILE

# %%
def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

# %% [markdown]
# ### CREATING A FUNCTION TO PLOT ERROR AND ACCURACY PLOT

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %% [markdown]
# ### SPLITTING THE DATASET FOR TRAINING AND TESTING

# %%
def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %% [markdown]
# ### CREATING THE CNN MODEL

# %%
def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model

# %% [markdown]
# ### PREDICTING THE GENRE USING THE MODEL

# %%
def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))

# %% [markdown]
# ### TESTING THE MODEL

# %%
if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[100]
    y_to_predict = y_test[100]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 11, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 64, 6, 32)        0
#  )
#
#  batch_normalization (BatchN  (None, 64, 6, 32)        128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 62, 4, 32)         9248
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 2, 32)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 31, 2, 32)        128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 30, 1, 32)         4128
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 1, 32)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 15, 1, 32)        128
#  hNormalization)
#
#  flatten (Flatten)           (None, 480)               0
#
#  dense (Dense)               (None, 64)                30784
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 45,514
# Trainable params: 45,322
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/30
# 188/188 [==============================] - 7s 35ms/step - loss: 2.4049 - accuracy: 0.2190 - val_loss: 1.8569 - val_accuracy: 0.3465
# Epoch 2/30
# 188/188 [==============================] - 7s 35ms/step - loss: 1.8303 - accuracy: 0.3650 - val_loss: 1.5475 - val_accuracy: 0.4339
# Epoch 3/30
# 188/188 [==============================] - 8s 42ms/step - loss: 1.6257 - accuracy: 0.4270 - val_loss: 1.4249 - val_accuracy: 0.4940
# Epoch 4/30
# 188/188 [==============================] - 7s 39ms/step - loss: 1.5027 - accuracy: 0.4739 - val_loss: 1.3474 - val_accuracy: 0.5220
# Epoch 5/30
# 188/188 [==============================] - 7s 39ms/step - loss: 1.4107 - accuracy: 0.4996 - val_loss: 1.2887 - val_accuracy: 0.5354
# Epoch 6/30
# 188/188 [==============================] - 7s 39ms/step - loss: 1.3551 - accuracy: 0.5169 - val_loss: 1.2458 - val_accuracy: 0.5541
# Epoch 7/30
# 188/188 [==============================] - 7s 39ms/step - loss: 1.2931 - accuracy: 0.5431 - val_loss: 1.2074 - val_accuracy: 0.5694
# Epoch 8/30
# 188/188 [==============================] - 7s 39ms/step - loss: 1.2476 - accuracy: 0.5538 - val_loss: 1.1742 - val_accuracy: 0.5888
# Epoch 9/30
# 188/188 [==============================] - 9s 47ms/step - loss: 1.1867 - accuracy: 0.5677 - val_loss: 1.1544 - val_accuracy: 0.5868
# Epoch 10/30
# 188/188 [==============================] - 7s 39ms/step - loss: 1.1568 - accuracy: 0.5865 - val_loss: 1.1095 - val_accuracy: 0.6061
# Epoch 11/30
# 188/188 [==============================] - 7s 39ms/step - loss: 1.1163 - accuracy: 0.6027 - val_loss: 1.0949 - val_accuracy: 0.6101
# Epoch 12/30
# 188/188 [==============================] - 7s 39ms/step - loss: 1.0737 - accuracy: 0.6164 - val_loss: 1.0622 - val_accuracy: 0.6235
# Epoch 13/30
# 188/188 [==============================] - 8s 41ms/step - loss: 1.0557 - accuracy: 0.6234 - val_loss: 1.0448 - val_accuracy: 0.6295
# Epoch 14/30
# 188/188 [==============================] - 8s 41ms/step - loss: 1.0393 - accuracy: 0.6314 - val_loss: 1.0215 - val_accuracy: 0.6395
# Epoch 15/30
# 188/188 [==============================] - 10s 54ms/step - loss: 0.9971 - accuracy: 0.6490 - val_loss: 1.0078 - val_accuracy: 0.6462
# Epoch 16/30
# 188/188 [==============================] - 8s 44ms/step - loss: 0.9744 - accuracy: 0.6506 - val_loss: 1.0047 - val_accuracy: 0.6509
# Epoch 17/30
# 188/188 [==============================] - 8s 41ms/step - loss: 0.9569 - accuracy: 0.6555 - val_loss: 0.9806 - val_accuracy: 0.6569
# Epoch 18/30
# 188/188 [==============================] - 7s 39ms/step - loss: 0.9471 - accuracy: 0.6685 - val_loss: 0.9645 - val_accuracy: 0.6595
# Epoch 19/30
# 188/188 [==============================] - 8s 43ms/step - loss: 0.9048 - accuracy: 0.6894 - val_loss: 0.9523 - val_accuracy: 0.6689
# Epoch 20/30
# 188/188 [==============================] - 7s 39ms/step - loss: 0.8866 - accuracy: 0.6870 - val_loss: 0.9295 - val_accuracy: 0.6876
# Epoch 21/30
# 188/188 [==============================] - 7s 38ms/step - loss: 0.8466 - accuracy: 0.7072 - val_loss: 0.9245 - val_accuracy: 0.6816
# Epoch 22/30
# 188/188 [==============================] - 9s 47ms/step - loss: 0.8603 - accuracy: 0.6920 - val_loss: 0.9076 - val_accuracy: 0.6969
# Epoch 23/30
# 188/188 [==============================] - 8s 42ms/step - loss: 0.8142 - accuracy: 0.7151 - val_loss: 0.8966 - val_accuracy: 0.6936
# Epoch 24/30
# 188/188 [==============================] - 7s 36ms/step - loss: 0.8073 - accuracy: 0.7192 - val_loss: 0.8815 - val_accuracy: 0.7103
# Epoch 25/30
# 188/188 [==============================] - 7s 35ms/step - loss: 0.7899 - accuracy: 0.7204 - val_loss: 0.8710 - val_accuracy: 0.7003
# Epoch 26/30
# 188/188 [==============================] - 7s 35ms/step - loss: 0.7702 - accuracy: 0.7269 - val_loss: 0.8611 - val_accuracy: 0.7103
# Epoch 27/30
# 188/188 [==============================] - 7s 35ms/step - loss: 0.7489 - accuracy: 0.7354 - val_loss: 0.8652 - val_accuracy: 0.7190
# Epoch 28/30
# 188/188 [==============================] - 7s 35ms/step - loss: 0.7470 - accuracy: 0.7446 - val_loss: 0.8548 - val_accuracy: 0.7130
# Epoch 29/30
# 188/188 [==============================] - 7s 35ms/step - loss: 0.7309 - accuracy: 0.7471 - val_loss: 0.8632 - val_accuracy: 0.7143
# Epoch 30/30
# 188/188 [==============================] - 7s 35ms/step - loss: 0.7065 - accuracy: 0.7590 - val_loss: 0.8714 - val_accuracy: 0.7156
# 79/79 - 1s - loss: 0.8588 - accuracy: 0.7020 - 622ms/epoch - 8ms/step
#
# Test accuracy: 0.7020424604415894
# Target: 2, Predicted label: [2]

# %% [markdown]
# AS THE ACCURACY OF THE MODEL IS 70.20% IT IS BETTER THAN THE NEURAL NETWORK MODEL
